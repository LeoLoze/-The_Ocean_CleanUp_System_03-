# %% [markdown]
# # System 03 - Constants and Sources
#
# This document keeps track of the constants used in the objective functions of `OceanCleanup_System03.ipynb`. For every constant, write down the value we use and where it comes from, so that we can trace our values back later. The values below are the current placeholders, so replace them when you have found a source.
#
# ## General
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `barrier_length` | 2200 | m | Total length of the barrier | Verhagen (2024)|
# | `uptime` | 0.7 | - | Fraction of the year the system is actively towing |The Ocean Cleanup, 2026| |
# | `rho_water` | 1025 | kg/m³ | Sea water density | - | |
#
# ## Plastic in the garbage patch (objectives 2 and 5)
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `plastic_density` | 5e-5 | kg/m² | Floating plastic mass per sea surface area (= 50 kg/km²) | Filho (2021) | |
# | `plastic_size_char` | 50 | mm | Characteristic size of the plastic size distribution | Liese (2026) | |
#
# ## Objective 1 - Cost
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `charter_cost` | 7.5e6 | EUR/yr | Fixed cost per system: two vessels + crew per year | The Ocean CleanUp (2024)| |
# | `material_cost` | 150 | EUR/m² | Barrier / skirt material cost per m² | Cleaner Ocean Foundation (2023) | |
# | `barrier_lifetime` | 5 | yr | Lifetime of the barrier | Tanis (2016) | |
# | `drag_coeff` | 0.85 | - | Drag coefficient of the barrier / skirt | | For low-porosity nets, Cd typically approaches 1.0, similar to a flat plate perpendiculat to flow. S03's design includes some porosity from water to pass through, reducing Cd relative to a solid barrier.  |
# | `prop_efficiency` | 0.6 | - | Propulsion efficiency of the towing vessels | Saettone (2021) | |
# | `fuel_cost` | 0.25 | EUR/kWh | Fuel cost per kWh of towing energy | | Fuel Cost per kWh = (Fuel Consumption per hour [L/h] * Fuel price [EUR/L])/Engine power delivered for towing [kW] |
#
# ## Objective 2 - Plastic removal
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `plastic_depth` | 5 | m | Depth scale of plastic concentration in the water column | Reisser, J (2015) | |
# | `v_critical` | 1.3 | m/s | Towing speed above which plastic escapes under the skirt |Erika (2023)
# | `escape_steepness` | 4 | - | How sharply retention drops above `v_critical` | | This parameter is a non-linear hydrodynamic penalty exponent (n). Below `v_critical` (1.3 m/s), capture efficiency is 1.0. Above this threshold, turbulent vortex shedding causes retention to drop sharply to the 4th power, modeling physical under-spill and penalizing high towing speeds in the optimizer.|
#
# ## Objective 3 - Fishing-area interference
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `safety_buffer` | 500 | m | Buffer around the system where fishing is not allowed | International Maritime Organization (IMO). (2020).  | IMO Publishing. Safety zones and navigation buffers around restricted maneuverability vessels (Rule 27 & Sectorial Safety Guidelines). |
#
# ## Objective 4 - Ecological risk
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `animal_density` | 2.1e-3 | 1/m³ | Density of vulnerable animals in the water column | The Great Pacific Garbage Patch (2026) | Plastic counts are roughly 1.8 trillon / 1.6x10e6 km2 = 1.125x10e6 pieces/km2. Animals are therefore at 1/180 of the number of plastics in the same volume. |
# | `v_avoid` | 0.75 | m/s | Speed at which animals can still escape the barrier | Erika (2023)| it is the same as v_critical, because the escape of the marine life and the downswelling is interlinked |
# | `mesh_ref` | 10 | mm | Reference (finest) mesh size | CSA Ocean Sciences Inc., 2023| |
#
# ## Objective 5 - Future plastic fragmentation
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `frag_factor` | 0.01 | - | Fraction of passing plastic that fragments at 1 m/s | The Ocean Cleanup. (2026) | System 002 achieved >99% capture by weight of floating plastics in high-density gyres. System 03 has improvements to achieve equal or better capture efficiency that System 002, so that number is taken as reference.|
#
# ## Constraint 1 - Maximum cable Tension
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `max_tension` | 550 | kN | Design allowable tension | | The exact allowable tension value for the System 03 mainline is confidential. For this development, we use a technical proxy based on offshore marine standards. A high-performance commercial rope (56 mm Dyneema®) with a Minimum Breaking Load (MBL) of 2,100 kN was used as a baseline. Applying a regulatory Factor of Safety (FoS) of 4.0 for dynamic ocean towing, the design allowable tension was established at 550 kN.|
# | `Cd` | 1.2 |  | Drag coefficient  | Gonzalez Jimenez, M.A. (2023) | |
#
# ## Constraint 2 - Maximum volume of the waste bag
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `max_value` | 1540 | m3 | Thorical waste bag volume | Ocean CleanUp (2026) | Based on structural dimensions - Length: 70 m; Width: 5.5 m; Depth: 4 m|
# | `K_vol` | 0.38 | - | Geometric scaling constant |  | The value 0,38 is a standard marine engineering shape factor that accounts for the flexible barrier deforming into a "u" shape (caternaty curve) under towing tension.|
#
# ## Constraint 3 - Vessel fuel autonomy
#
# | Constant | Value | Unit | Description | Source | Notes |
# |---|---|---|---|---|---|
# | `K_base` | 1740.74 | L/(H * System * (m/2)**3) |  Baseline Fleet Hydrodynamic Propulsion Coefficient | Environmental Impact Assessment (2023) |We utilize the real-world empirical boundary data from the official Environmental Impact Assessment and applying naval fluid mechanics principles, the constants were algebraically solved to satisfy the system's energy balance under an intermediate operational state.|
# | `K_weight` | 668.80 | m/s | L/(H * System * (m/2)**2) | Payload-Induced Induced Drag Penalty Coefficient | Environmental Impact Assessment (2023) |We utilize the real-world empirical boundary data from the official Environmental Impact Assessment and applying naval fluid mechanics principles, the constants were algebraically solved to satisfy the system's energy balance under an intermediate operational state.|
# | `fuel_max` | 1.25e6 | L | Total fuel capacity | Maersk Supply Service Fleet | The vessels are Maersk Tender, and from their technique |
#
# ## References
# #we need to sort this alphabetically
# 1. Verhagen, K. (2024, March 13). System 03: A Beginner’s Guide. The Ocean Cleanup. https://theoceancleanup.com/updates/system-03-a-beginners-guide/
# 2. The Ocean Cleanup. (2026, July 29). Modelling the cleanup of the North Pacific Garbage Patch based on 3 years of operational experience | Scientific Publication | The Ocean Cleanup. https://theoceancleanup.com/scientific-publications/modelling-the-cleanup-of-the-north-pacific-garbage-patch-based-on-3-years-of-operational-experience/
# 3. Filho, W. L. (2021). Garbage Patches and Their Environmental Implications in a Plastisphere. MDPI. https://doi.org/10.3390/jmse9111289
# 4. CSA Ocean Sciences Inc. (2023). The ocean cleanup Final S03 environmental impact assessment. https://assets.theoceancleanup.com/app/uploads/2023/08/System-03-Environmental-Impact-Assessment-The-Ocean-Cleanup.pdf
# 5. Erika. (2023, July 7). System 002: Mid-Term evaluation. The Ocean Cleanup. https://theoceancleanup.com/updates/system-002-mid-term-evaluation/
# 6. Liese, N., Puskic, P., Royer, S.-J., & Kooi, M. (2026). A comparative analysis of 2D, visible light imaging technologies for describing the physical properties of micro- and mesoplastics (0.5 to 50 mm). Marine Pollution Bulletin, 203, 116410. doi.org https://www.sciencedirect.com/science/article/pii/S0025326X2600367X
# 7. The Ocean Cleanup. (2024, September 6). The Great Pacific Garbage Patch can be Cleaned for $7.5 Billion  https://theoceancleanup.com/press/press-releases/the-great-pacific-garbage-patch-can-be-cleaned-for-7-5-billion/
# 8. Cleaner Ocean Foundation. (2023). The Ocean Cleanup Project Boyan Slat: Floating boom ocean current drag net & river cleaning barges. Cleaner Oceans Foundation Ltd. https://www.oceansplasticleanup.com/Cleaning_Up_Operations/Boyan_Slat_Ocean_Cleanup_Project_The.htm
# 9. Tanis, A. H. (2016). The Ocean Cleanup Barrier: A hydro-elastic model for fatigue lifetime assessment of The Ocean Cleanup barrier (Master's thesis, Delft University of Technology). https://repository.tudelft.nl/record/uuid:6a62d2a0-cf7a-4c66-9edf-2d7e1bef26ac#files
# 10. Saettone, S., Taskar, B., Steen, S., & Andersen, P. (2021). Experimental measurements of propulsive factors in following and head waves. https://www.sciencedirect.com/science/article/pii/S0141118721001164
# 11. Reisser, J., Slat, B., et al. (2015). https://bg.copernicus.org/articles/12/1249/2015/
# 12. The Great Pacific Garbage Patch (2026). https://theoceancleanup.com/great-pacific-garbage-patch/
# 13. The Ocean Cleanup. (2026). System 002 Proven Technology. Milestones. https://theoceancleanup.com/milestones/system-002/
# 14. Gonzalez Jimenez, M.A., Rakotonirina, D., Sainte-Rose, B., Cox, D.J., On the Digital Twin of the Ocean Cleanup Systems—Part I: Calibration of the Drag Coefficients of a Netted Screen in OrcaFlex Using CFD and Full-Scale Experiments, Journal of Marine Science and Engineering, 2023. DOI: 10.3390/jmse11101943
# 15. The Ocean Cleanup. (2026). System 03 A Beginner's Guide. https://theoceancleanup.com/updates/system-03-a-beginners-guide/
# 16. The Ocean Cleanup (2023) Final S03 Environmental Impact Assessment. https://assets.theoceancleanup.com/app/uploads/2023/08/System-03-Environmental-Impact-Assessment-The-Ocean-Cleanup.pdf
# 17. Ships and Oil. (s.f.). Maersk Supply Service Fleet: Maersk Tender Specification. Ships and Oil Maritime Directory. https://www.maersksupplyservice.com/fleet/
